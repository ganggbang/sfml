# %% [markdown]
# # SkillFactory
# ## Введение в ML, введение в sklearn

# %% [markdown]
# В этом задании мы с вами рассмотрим данные с конкурса [Задача предсказания отклика клиентов ОТП Банка](http://www.machinelearning.ru/wiki/index.php?title=%D0%97%D0%B0%D0%B4%D0%B0%D1%87%D0%B0_%D0%BF%D1%80%D0%B5%D0%B4%D1%81%D0%BA%D0%B0%D0%B7%D0%B0%D0%BD%D0%B8%D1%8F_%D0%BE%D1%82%D0%BA%D0%BB%D0%B8%D0%BA%D0%B0_%D0%BA%D0%BB%D0%B8%D0%B5%D0%BD%D1%82%D0%BE%D0%B2_%D0%9E%D0%A2%D0%9F_%D0%91%D0%B0%D0%BD%D0%BA%D0%B0_%28%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%29)

# %%
from transliterate import translit, get_available_language_codes
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,5)


#print()

# %% [markdown]
# ### Грузим данные

# %%
df_desc = pd.read_csv('data/otp_description.csv', sep='\t', encoding='utf-8')
df_desc
# Out:
#                           ПОЛЕ  \
# 0                 AGREEMENT_RK
# 1                          AGE
# 2            SOCSTATUS_WORK_FL
# 3            SOCSTATUS_PENS_FL
# 4                       GENDER
# 5                  CHILD_TOTAL
# 6                   DEPENDANTS
# 7                    EDUCATION
# 8               MARITAL_STATUS
# 9                 GEN_INDUSTRY
# 10                   GEN_TITLE
# 11                ORG_TP_STATE
# 12             ORG_TP_FCAPITAL
# 13                     JOB_DIR
# 14               FAMILY_INCOME
# 15             PERSONAL_INCOME
# 16        REG_ADDRESS_PROVINCE
# 17       FACT_ADDRESS_PROVINCE
# 18     POSTAL_ADDRESS_PROVINCE
# 19                 TP_PROVINCE
# 20                   REGION_NM
# 21                 REG_FACT_FL
# 22                FACT_POST_FL
# 23                 REG_POST_FL
# 24            REG_FACT_POST_FL
# 25         REG_FACT_POST_TP_FL
# 26              FL_PRESENCE_FL
# 27                    OWN_AUTO
# 28                 AUTO_RUS_FL
# 29              HS_PRESENCE_FL
# 30             COT_PRESENCE_FL
# 31             GAR_PRESENCE_FL
# 32            LAND_PRESENCE_FL
# 33                      CREDIT
# 34                        TERM
# 35                 FST_PAYMENT
# 36              DL_DOCUMENT_FL
# 37             GPF_DOCUMENT_FL
# 38            FACT_LIVING_TERM
# 39                   WORK_TIME
# 40               FACT_PHONE_FL
# 41                REG_PHONE_FL
# 42                GEN_PHONE_FL
# 43              LOAN_NUM_TOTAL
# 44             LOAN_NUM_CLOSED
# 45               LOAN_NUM_PAYM
# 46                LOAN_DLQ_NUM
# 47                LOAN_MAX_DLQ
# 48            LOAN_AVG_DLQ_AMT
# 49            LOAN_MAX_DLQ_AMT
# 50  PREVIOUS_CARD_NUM_UTILIZED
#
#                                              ОПИСАНИЕ
# 0          уникальный идентификатор объекта в выборке
# 1                                     возраст клиента
# 2   социальный статус клиента относительно работы ...
# 3   социальный статус клиента относительно пенсии ...
# 4                 пол клиента (1- женщины, 0-мужчины)
# 5                            количество детей клиента
# 6                       количество иждивенцев клиента
# 7                                         образование
# 8                                  семейное положение
# 9                              отрасль работы клиента
# 10                                          должность
# 11                       форма собственности компании
# 12                  отношение к иностранному капиталу
# 13          направление деятельности в нутри компании
# 14               семейный доход (несколько категорий)
# 15                    личный доход клиента (в рублях)
# 16                        область регистрации клиента
# 17            область фактического пребывания клиента
# 18                             почтовый адрес область
# 19  область торговой точки, где клиент брал послед...
# 20                                          регион РФ
# 21  адрес регистрации и адрес фактического пребыва...
# 22  адрес фактического пребывания клиента и его по...
# 23  адрес регистрации клиента и его почтовый адрес...
# 24  почтовый, фактический и адрес регистрации совп...
# 25  область регистрации, фактического пребывания, ...
# 26  наличие в собственности квартиры (1 - есть, 0 ...
# 27                кол-во автомобилей в собственности
# 28  наличие в собственности автомобиля российского...
# 29  наличие в собственности загородного дома (1 - ...
# 30  наличие в собственности котеджа (1 - есть, 0 -...
# 31  наличие в собственности гаража (1 - есть, 0 - ...
# 32  наличие в собственности земельного участка (1 ...
# 33        сумма последнего кредита клиента (в рублях)
# 34                                       срок кредита
# 35                    первоначальный взнос (в рублях)
# 36  в анкете клиент указал водительское удостовере...
# 37  в анкете клиен указал ГПФ (1 - указал, 0 - не ...
# 38  количество месяцев проживания по месту фактиче...
# 39          время работы на текущем месте (в месяцах)
# 40  наличие в заявке телефона по фактическому мест...
# 41     наличие в заявке телефона по месту регистрации
# 42                 наличие в заявке рабочего телефона
# 43                            количество ссуд клиента
# 44                 количество погашенных ссуд клиента
# 45         количество платежей, которые сделал клиент
# 46          количество просрочек, допущенных клиентом
# 47  номер максимальной просрочки, допущенной клиентом
# 48                 средняя сумма просрочки (в рублях)
# 49            максимальная сумма просрочки (в рублях)
# 50  количество уже утилизированных карт ( если пус...

# %% [markdown]
# Считаем описание данных

# %% [markdown]
# Считаем обучающую выборки и тестовую (которую мы как бы не видим)

# %% [markdown]
# ## Объединим две выборки
#
# Так как пока мы пока не умеем работать sklearn  Pipeline, то для того, чтобы после предобработки столбцы в двух выборках находились на своих местах.
#
# Для того, чтобы в дальнейшем отделить их введем новый столбец "sample"

# %%
df_train = pd.read_csv('data/otp_train.csv', sep='\t', encoding='utf-8')
df_train.shape
df_test = pd.read_csv('data/otp_test.csv', sep='\t', encoding='utf-8')
df_test.shape
df_train.loc[:, 'sample'] = 'train'
df_test.loc[:, 'sample'] = 'test'
df = df_test.append(df_train).reset_index(drop=True)
df.shape
# Out:
# (30133, 53)

# %%
df = df.drop(['AGREEMENT_RK', 'TP_PROVINCE','REG_ADDRESS_PROVINCE', 'FACT_ADDRESS_PROVINCE','POSTAL_ADDRESS_PROVINCE', 'PREVIOUS_CARD_NUM_UTILIZED'],axis=1)
df = df[~df['GEN_INDUSTRY'].isnull()]
df = df[~df['REGION_NM'].isnull()]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27418 entries, 0 to 30132
# Data columns (total 47 columns):
# TARGET                 27418 non-null int64
# AGE                    27418 non-null int64
# SOCSTATUS_WORK_FL      27418 non-null int64
# SOCSTATUS_PENS_FL      27418 non-null int64
# GENDER                 27418 non-null int64
# CHILD_TOTAL            27418 non-null int64
# DEPENDANTS             27418 non-null int64
# EDUCATION              27418 non-null object
# MARITAL_STATUS         27418 non-null object
# GEN_INDUSTRY           27418 non-null object
# GEN_TITLE              27418 non-null object
# ORG_TP_STATE           27418 non-null object
# ORG_TP_FCAPITAL        27417 non-null object
# JOB_DIR                27418 non-null object
# FAMILY_INCOME          27418 non-null object
# PERSONAL_INCOME        27418 non-null object
# REGION_NM              27418 non-null object
# REG_FACT_FL            27418 non-null int64
# FACT_POST_FL           27418 non-null int64
# REG_POST_FL            27418 non-null int64
# REG_FACT_POST_FL       27418 non-null int64
# REG_FACT_POST_TP_FL    27418 non-null int64
# FL_PRESENCE_FL         27418 non-null int64
# OWN_AUTO               27418 non-null int64
# AUTO_RUS_FL            27418 non-null int64
# HS_PRESENCE_FL         27418 non-null int64
# COT_PRESENCE_FL        27418 non-null int64
# GAR_PRESENCE_FL        27418 non-null int64
# LAND_PRESENCE_FL       27418 non-null int64
# CREDIT                 27418 non-null object
# TERM                   27418 non-null int64
# FST_PAYMENT            27418 non-null object
# DL_DOCUMENT_FL         27418 non-null int64
# GPF_DOCUMENT_FL        27418 non-null int64
# FACT_LIVING_TERM       27418 non-null int64
# WORK_TIME              27414 non-null float64
# FACT_PHONE_FL          27418 non-null int64
# REG_PHONE_FL           27418 non-null int64
# GEN_PHONE_FL           27418 non-null int64
# LOAN_NUM_TOTAL         27418 non-null int64
# LOAN_NUM_CLOSED        27418 non-null int64
# LOAN_NUM_PAYM          27418 non-null int64
# LOAN_DLQ_NUM           27418 non-null int64
# LOAN_MAX_DLQ           27418 non-null int64
# LOAN_AVG_DLQ_AMT       27418 non-null object
# LOAN_MAX_DLQ_AMT       27418 non-null object
# sample                 27418 non-null object
# dtypes: float64(1), int64(31), object(15)
# memory usage: 10.0+ MB

# %%
df.loc[df['MARITAL_STATUS'] != u'Состою в браке', 'MARITAL_STATUS'] = 0
df.loc[df['MARITAL_STATUS'] == u'Состою в браке', 'MARITAL_STATUS'] = 1

df.loc[df['ORG_TP_FCAPITAL'] == u'Без участия', 'ORG_TP_FCAPITAL'] = 0
df.loc[df['ORG_TP_FCAPITAL'] == u'С участием', 'ORG_TP_FCAPITAL'] = 1

df.loc[df['WORK_TIME'].isnull(), 'WORK_TIME'] = df['WORK_TIME'].median()
df.loc[df['ORG_TP_FCAPITAL'].isnull(), 'ORG_TP_FCAPITAL'] = df['ORG_TP_FCAPITAL'].mode().iloc[0]
#df.loc[df['TP_PROVINCE'].isnull(), 'TP_PROVINCE'] = df['REGION_NM'].median()

#df[df['WORK_TIME'].isnull()]['WORK_TIME']
#df['REGION_NM']

# %% [markdown]
# ### Чуть-чуть посмотрим на данные

# %% [markdown]
# Посмотрим типы данных и их заполняемость

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27418 entries, 0 to 30132
# Data columns (total 47 columns):
# TARGET                 27418 non-null int64
# AGE                    27418 non-null int64
# SOCSTATUS_WORK_FL      27418 non-null int64
# SOCSTATUS_PENS_FL      27418 non-null int64
# GENDER                 27418 non-null int64
# CHILD_TOTAL            27418 non-null int64
# DEPENDANTS             27418 non-null int64
# EDUCATION              27418 non-null object
# MARITAL_STATUS         27418 non-null int64
# GEN_INDUSTRY           27418 non-null object
# GEN_TITLE              27418 non-null object
# ORG_TP_STATE           27418 non-null object
# ORG_TP_FCAPITAL        27418 non-null int64
# JOB_DIR                27418 non-null object
# FAMILY_INCOME          27418 non-null object
# PERSONAL_INCOME        27418 non-null object
# REGION_NM              27418 non-null object
# REG_FACT_FL            27418 non-null int64
# FACT_POST_FL           27418 non-null int64
# REG_POST_FL            27418 non-null int64
# REG_FACT_POST_FL       27418 non-null int64
# REG_FACT_POST_TP_FL    27418 non-null int64
# FL_PRESENCE_FL         27418 non-null int64
# OWN_AUTO               27418 non-null int64
# AUTO_RUS_FL            27418 non-null int64
# HS_PRESENCE_FL         27418 non-null int64
# COT_PRESENCE_FL        27418 non-null int64
# GAR_PRESENCE_FL        27418 non-null int64
# LAND_PRESENCE_FL       27418 non-null int64
# CREDIT                 27418 non-null object
# TERM                   27418 non-null int64
# FST_PAYMENT            27418 non-null object
# DL_DOCUMENT_FL         27418 non-null int64
# GPF_DOCUMENT_FL        27418 non-null int64
# FACT_LIVING_TERM       27418 non-null int64
# WORK_TIME              27418 non-null float64
# FACT_PHONE_FL          27418 non-null int64
# REG_PHONE_FL           27418 non-null int64
# GEN_PHONE_FL           27418 non-null int64
# LOAN_NUM_TOTAL         27418 non-null int64
# LOAN_NUM_CLOSED        27418 non-null int64
# LOAN_NUM_PAYM          27418 non-null int64
# LOAN_DLQ_NUM           27418 non-null int64
# LOAN_MAX_DLQ           27418 non-null int64
# LOAN_AVG_DLQ_AMT       27418 non-null object
# LOAN_MAX_DLQ_AMT       27418 non-null object
# sample                 27418 non-null object
# dtypes: float64(1), int64(33), object(13)
# memory usage: 10.0+ MB

# %% [markdown]
# Видим, что часть данных - object, скорее всего стоки.
#
#
# Давайте выведем эти значения для каждого столбца

# %% [markdown]
# Mожно заметить что некоторые переменные, которые обозначены как строки (например PERSONAL_INCOME) на самом деле числа, но по какой-то причине были распознаны как строки
#
# Причина же что использовалась запятая для разделения не целой части числа..

# %%
df['PERSONAL_INCOME'] = df['PERSONAL_INCOME'].map(lambda x: x.replace(',', '.')).astype('float')
df['CREDIT'] = df['CREDIT'].map(lambda x: x.replace(',', '.')).astype('float')
df['FST_PAYMENT'] = df['FST_PAYMENT'].map(lambda x: x.replace(',', '.')).astype('float')
df['LOAN_AVG_DLQ_AMT'] = df['LOAN_AVG_DLQ_AMT'].map(lambda x: x.replace(',', '.')).astype('float')
df['LOAN_MAX_DLQ_AMT'] = df['LOAN_MAX_DLQ_AMT'].map(lambda x: x.replace(',', '.')).astype('float')
#df[['CREDIT']]

# %% [markdown]
# Перекодировать их можно например так:

# %%
education = [u'Ученая степень', u'Неполное среднее', u'Неоконченное высшее', u'Два и более высших образования', u'Высшее', u'Среднее', u'Среднее специальное']
gen_industry = [u'Информационные услуги', u'Туризм', u'Торговля', u'Строительство', u'СМИ/Реклама/PR-агенства', u'Сельское хозяйство', u'Управляющая компания', u'Маркетинг', u'Коммунальное хоз-во/Дорожные службы', u'Здравоохранение', u'ЧОП/Детективная д-ть', u'Химия/Парфюмерия/Фармацевтика', u'Ресторанный бизнес/Общественное питание', u'Логистика', u'Юридические услуги/нотариальные услуги', u'Банк/Финансы', u'Наука', u'Подбор персонала', u'Недвижимость', u'Транспорт', u'Сборочные производства', u'Информационные технологии', u'Государственная служба', u'Развлечения/Искусство', u'Страхование', u'Нефтегазовая промышленность', u'Энергетика', u'Салоны красоты и здоровья', u'Металлургия/Промышленность/Машиностроение', u'Другие сферы', u'Образование']
gen_title = [u'Партнер', u'Рабочий', u'Работник сферы услуг', u'Другое', u'Военнослужащий по контракту', u'Руководитель среднего звена', u'Индивидуальный предприниматель', u'Руководитель высшего звена', u'Руководитель низшего звена', u'Специалист', u'Высококвалифиц. специалист', u'Служащий']
org_tp_state = [u'Частная ком. с инос. капиталом', u'Некоммерческая организация', u'Индивидуальный предприниматель', u'Государственная комп./учреж.', u'Частная компания']
job_dir = [u'Вспомогательный техперсонал', u'Кадровая служба и секретариат', u'Реклама и маркетинг', u'Бухгалтерия, финансы, планир.', u'Юридическая служба', u'Служба безопасности', u'Адм-хоз. и трансп. службы', u'Участие в основ. деятельности', u'Снабжение и сбыт', u'Пр-техн. обесп. и телеком.']
family_income = [ u'до 5000 руб.', u'от 20000 до 50000 руб.', u'от 10000 до 20000 руб.', u'свыше 50000 руб.', u'от 5000 до 10000 руб.']
#tp_province = [u'Калининградская область', u'Ульяновская область', u'Пермская область', u'Сахалинская область', u'Омская область', u'Орловская область', u'Ставропольский край', u'Новгородская область', u'Воронежская область', u'Краснодарский край', u'Самарская область', u'Карелия', u'Кемеровская область', u'Смоленская область', u'Владимирская область', u'Якутия', u'Чувашия', u'Тульская область', u'Бурятия', u'Нижегородская область', u'Ханты-Мансийский АО', u'Архангельская область', u'Псковская область', u'Липецкая область', u'Кировская область', u'Свердловская область', u'Ярославская область', u'Кабардино-Балкария', u'Мурманская область', u'Башкирия', u'Приморский край', u'Москва', u'Тамбовская область', u'Пензенская область', u'Калужская область', u'Рязанская область', u'Челябинская область', u'Хабаровский край', u'Горный Алтай', u'Мордовская республика', u'Курская область', u'Тюменская область', u'Костромская область', u'Марийская республика', u'Адыгея', u'Брянская область', u'Амурская область', u'Удмуртия', u'Волгоградская область', u'Астраханская область', u'Иркутская область', u'Тверская область', u'Курганская область', u'Красноярский край', u'Читинская область', u'Санкт-Петербург', u'Белгородская область', u'Оренбургская область', u'Алтайский край', u'Ивановская область', u'Вологодская область', u'Камчатская область', u'Коми', u'Новосибирская область', u'Магаданская область', u'Еврейская АО', u'Томская область', u'Татарстан', u'Ростовская область', u'Саратовская область']
region_num = [ u'ЗАПАДНО-СИБИРСКИЙ', u'ВОСТОЧНО-СИБИРСКИЙ', u'ПРИВОЛЖСКИЙ', u'ЮЖНЫЙ', u'ЦЕНТРАЛЬНЫЙ ОФИС', u'ПОВОЛЖСКИЙ', u'ДАЛЬНЕВОСТОЧНЫЙ', u'ЦЕНТРАЛЬНЫЙ 1', u'ЦЕНТРАЛЬНЫЙ 2', u'СЕВЕРО-ЗАПАДНЫЙ', u'УРАЛЬСКИЙ']

df['EDUCATION'] = df['EDUCATION'].map(lambda x: education.index(x)).astype(int)
df['GEN_INDUSTRY'] = df['GEN_INDUSTRY'].map(lambda x: gen_industry.index(x))
df['GEN_TITLE'] = df['GEN_TITLE'].map(lambda x: gen_title.index(x))
df['ORG_TP_STATE'] = df['ORG_TP_STATE'].map(lambda x: org_tp_state.index(x))
df['JOB_DIR'] = df['JOB_DIR'].map(lambda x: job_dir.index(x))
#df['TP_PROVINCE'] = df['TP_PROVINCE'].map(lambda x: tp_province.index(x))
df['REGION_NM'] = df['REGION_NM'].map(lambda x: region_num.index(x))
df['FAMILY_INCOME'] = df['FAMILY_INCOME'].map(lambda x: family_income.index(x))

# %% [markdown]
# Такой эффект наблюдается в столбцах `PERSONAL_INCOME`, `CREDIT`, `FST_PAYMENT`, `LOAN_AVG_DLQ_AMT`, `LOAN_MAX_DLQ_AMT`

# %%
df.info()
#df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27418 entries, 0 to 30132
# Data columns (total 47 columns):
# TARGET                 27418 non-null int64
# AGE                    27418 non-null int64
# SOCSTATUS_WORK_FL      27418 non-null int64
# SOCSTATUS_PENS_FL      27418 non-null int64
# GENDER                 27418 non-null int64
# CHILD_TOTAL            27418 non-null int64
# DEPENDANTS             27418 non-null int64
# EDUCATION              27418 non-null int64
# MARITAL_STATUS         27418 non-null int64
# GEN_INDUSTRY           27418 non-null int64
# GEN_TITLE              27418 non-null int64
# ORG_TP_STATE           27418 non-null int64
# ORG_TP_FCAPITAL        27418 non-null int64
# JOB_DIR                27418 non-null int64
# FAMILY_INCOME          27418 non-null int64
# PERSONAL_INCOME        27418 non-null float64
# REGION_NM              27418 non-null int64
# REG_FACT_FL            27418 non-null int64
# FACT_POST_FL           27418 non-null int64
# REG_POST_FL            27418 non-null int64
# REG_FACT_POST_FL       27418 non-null int64
# REG_FACT_POST_TP_FL    27418 non-null int64
# FL_PRESENCE_FL         27418 non-null int64
# OWN_AUTO               27418 non-null int64
# AUTO_RUS_FL            27418 non-null int64
# HS_PRESENCE_FL         27418 non-null int64
# COT_PRESENCE_FL        27418 non-null int64
# GAR_PRESENCE_FL        27418 non-null int64
# LAND_PRESENCE_FL       27418 non-null int64
# CREDIT                 27418 non-null float64
# TERM                   27418 non-null int64
# FST_PAYMENT            27418 non-null float64
# DL_DOCUMENT_FL         27418 non-null int64
# GPF_DOCUMENT_FL        27418 non-null int64
# FACT_LIVING_TERM       27418 non-null int64
# WORK_TIME              27418 non-null float64
# FACT_PHONE_FL          27418 non-null int64
# REG_PHONE_FL           27418 non-null int64
# GEN_PHONE_FL           27418 non-null int64
# LOAN_NUM_TOTAL         27418 non-null int64
# LOAN_NUM_CLOSED        27418 non-null int64
# LOAN_NUM_PAYM          27418 non-null int64
# LOAN_DLQ_NUM           27418 non-null int64
# LOAN_MAX_DLQ           27418 non-null int64
# LOAN_AVG_DLQ_AMT       27418 non-null float64
# LOAN_MAX_DLQ_AMT       27418 non-null float64
# sample                 27418 non-null object
# dtypes: float64(6), int64(40), object(1)
# memory usage: 10.0+ MB

# %% [markdown]
# ### Теперь ваше небольшое исследование

# %% [markdown]
# #### Задание 1. Есть ли пропуски в данных? Что с ними сделать?
#
# (единственного верного ответа нет - аргументируйте)

# %% [markdown]
# Я удалил все строки в которых ['GEN_INDUSTRY'].isnull() разница в несколько % данных, а указывать вместо пусого значения мениану или моду считаю не логичным
# в [WORK_TIME'].isnull() я положил медиану df['WORK_TIME'].median()
# в ['ORG_TP_FCAPITAL'].isnull() я положил моду

# %%
tmp = df_train[['GEN_INDUSTRY','GEN_TITLE','ORG_TP_STATE','ORG_TP_FCAPITAL','JOB_DIR','TP_PROVINCE','REGION_NM','WORK_TIME','PREVIOUS_CARD_NUM_UTILIZED']]
tmp.head()
# Out:
#                 GEN_INDUSTRY                    GEN_TITLE  \
# 0                   Торговля                      Рабочий
# 1                   Торговля                      Рабочий
# 2  Информационные технологии                   Специалист
# 3                Образование  Руководитель среднего звена
# 4     Государственная служба                   Специалист
#
#                      ORG_TP_STATE ORG_TP_FCAPITAL  \
# 0                Частная компания     Без участия
# 1  Индивидуальный предприниматель     Без участия
# 2    Государственная комп./учреж.     Без участия
# 3    Государственная комп./учреж.     Без участия
# 4    Государственная комп./учреж.     Без участия
#
#                          JOB_DIR           TP_PROVINCE           REGION_NM  \
# 0    Вспомогательный техперсонал  Оренбургская область          ПОВОЛЖСКИЙ
# 1  Участие в основ. деятельности   Ставропольский край               ЮЖНЫЙ
# 2  Участие в основ. деятельности     Иркутская область  ВОСТОЧНО-СИБИРСКИЙ
# 3  Участие в основ. деятельности    Ростовская область               ЮЖНЫЙ
# 4  Участие в основ. деятельности   Ставропольский край               ЮЖНЫЙ
#
#    WORK_TIME  PREVIOUS_CARD_NUM_UTILIZED
# 0       18.0                         NaN
# 1       97.0                         NaN
# 2       84.0                         NaN
# 3      168.0                         NaN
# 4      101.0                         NaN

# %% [markdown]
# #### Задание 2. Есть ли категориальные признаки? Что с ними делать?

# %% [markdown]
# я пронумеровал их выставил им айдишники

# %%
tmp2 = df_train[['EDUCATION','MARITAL_STATUS','GEN_INDUSTRY','GEN_TITLE','ORG_TP_STATE','ORG_TP_FCAPITAL','JOB_DIR','FAMILY_INCOME','PERSONAL_INCOME','REG_ADDRESS_PROVINCE','FACT_ADDRESS_PROVINCE','POSTAL_ADDRESS_PROVINCE','TP_PROVINCE','REGION_NM']]
tmp2.head()
# Out:
#              EDUCATION  MARITAL_STATUS               GEN_INDUSTRY  \
# 0  Среднее специальное  Состою в браке                   Торговля
# 1              Среднее  Состою в браке                   Торговля
# 2     Неполное среднее  Состою в браке  Информационные технологии
# 3               Высшее  Состою в браке                Образование
# 4              Среднее  Состою в браке     Государственная служба
#
#                      GEN_TITLE                    ORG_TP_STATE  \
# 0                      Рабочий                Частная компания
# 1                      Рабочий  Индивидуальный предприниматель
# 2                   Специалист    Государственная комп./учреж.
# 3  Руководитель среднего звена    Государственная комп./учреж.
# 4                   Специалист    Государственная комп./учреж.
#
#   ORG_TP_FCAPITAL                        JOB_DIR           FAMILY_INCOME  \
# 0     Без участия    Вспомогательный техперсонал  от 10000 до 20000 руб.
# 1     Без участия  Участие в основ. деятельности  от 10000 до 20000 руб.
# 2     Без участия  Участие в основ. деятельности  от 10000 до 20000 руб.
# 3     Без участия  Участие в основ. деятельности  от 20000 до 50000 руб.
# 4     Без участия  Участие в основ. деятельности  от 10000 до 20000 руб.
#
#   PERSONAL_INCOME  REG_ADDRESS_PROVINCE FACT_ADDRESS_PROVINCE  \
# 0            5000  Оренбургская область  Оренбургская область
# 1           12000    Кабардино-Балкария    Кабардино-Балкария
# 2            9000     Иркутская область     Иркутская область
# 3           25000    Ростовская область    Ростовская область
# 4           12000    Кабардино-Балкария    Кабардино-Балкария
#
#   POSTAL_ADDRESS_PROVINCE           TP_PROVINCE           REGION_NM
# 0    Оренбургская область  Оренбургская область          ПОВОЛЖСКИЙ
# 1      Кабардино-Балкария   Ставропольский край               ЮЖНЫЙ
# 2       Иркутская область     Иркутская область  ВОСТОЧНО-СИБИРСКИЙ
# 3      Ростовская область    Ростовская область               ЮЖНЫЙ
# 4      Кабардино-Балкария   Ставропольский край               ЮЖНЫЙ

# %% [markdown]
# #### Задание 3. Фунция предобработки

# %% [markdown]
# Напишите функцию, которая бы
#
# * Удаляло идентификатор `AGREEMENT_RK`
# * Избавлялась от проблем с '.' и ',' в стобцах PERSONAL_INCOME, CREDIT, FST_PAYMENT, LOAN_AVG_DLQ_AMT, LOAN_MAX_DLQ_AMT
# * Что-то делала с пропусками
# * Кодировала категориальные признаки
#
# В результате, ваш датафрейм должен содержать только числа и не содержать пропусков!

# %%
df_train = pd.read_csv('data/otp_train.csv', sep='\t', encoding='utf-8')
df_train.shape
df_test = pd.read_csv('data/otp_test.csv', sep='\t', encoding='utf-8')
df_test.shape
df_train.loc[:, 'sample'] = 'train'
df_test.loc[:, 'sample'] = 'test'
df = df_test.append(df_train).reset_index(drop=True)
df.shape
# Out:
# (30133, 53)

# %%
def preproc_data(df_input):
    df = df_input.copy()
    df = df.drop(['AGREEMENT_RK', 'TP_PROVINCE','REG_ADDRESS_PROVINCE', 'FACT_ADDRESS_PROVINCE','POSTAL_ADDRESS_PROVINCE', 'PREVIOUS_CARD_NUM_UTILIZED'],axis=1)
    df = df[~df['GEN_INDUSTRY'].isnull()]
    df = df[~df['REGION_NM'].isnull()]
    df.loc[df['MARITAL_STATUS'] != u'Состою в браке', 'MARITAL_STATUS'] = 0
    df.loc[df['MARITAL_STATUS'] == u'Состою в браке', 'MARITAL_STATUS'] = 1

    df.loc[df['ORG_TP_FCAPITAL'] == u'Без участия', 'ORG_TP_FCAPITAL'] = 0
    df.loc[df['ORG_TP_FCAPITAL'] == u'С участием', 'ORG_TP_FCAPITAL'] = 1

    df.loc[df['WORK_TIME'].isnull(), 'WORK_TIME'] = df['WORK_TIME'].median()
    df.loc[df['ORG_TP_FCAPITAL'].isnull(), 'ORG_TP_FCAPITAL'] = df['ORG_TP_FCAPITAL'].mode().iloc[0]
    df['PERSONAL_INCOME'] = df['PERSONAL_INCOME'].map(lambda x: x.replace(',', '.')).astype('float')
    df['CREDIT'] = df['CREDIT'].map(lambda x: x.replace(',', '.')).astype('float')
    df['FST_PAYMENT'] = df['FST_PAYMENT'].map(lambda x: x.replace(',', '.')).astype('float')
    df['LOAN_AVG_DLQ_AMT'] = df['LOAN_AVG_DLQ_AMT'].map(lambda x: x.replace(',', '.')).astype('float')
    df['LOAN_MAX_DLQ_AMT'] = df['LOAN_MAX_DLQ_AMT'].map(lambda x: x.replace(',', '.')).astype('float')
    
    education = [u'Ученая степень', u'Неполное среднее', u'Неоконченное высшее', u'Два и более высших образования', u'Высшее', u'Среднее', u'Среднее специальное']
    gen_industry = [u'Информационные услуги', u'Туризм', u'Торговля', u'Строительство', u'СМИ/Реклама/PR-агенства', u'Сельское хозяйство', u'Управляющая компания', u'Маркетинг', u'Коммунальное хоз-во/Дорожные службы', u'Здравоохранение', u'ЧОП/Детективная д-ть', u'Химия/Парфюмерия/Фармацевтика', u'Ресторанный бизнес/Общественное питание', u'Логистика', u'Юридические услуги/нотариальные услуги', u'Банк/Финансы', u'Наука', u'Подбор персонала', u'Недвижимость', u'Транспорт', u'Сборочные производства', u'Информационные технологии', u'Государственная служба', u'Развлечения/Искусство', u'Страхование', u'Нефтегазовая промышленность', u'Энергетика', u'Салоны красоты и здоровья', u'Металлургия/Промышленность/Машиностроение', u'Другие сферы', u'Образование']
    gen_title = [u'Партнер', u'Рабочий', u'Работник сферы услуг', u'Другое', u'Военнослужащий по контракту', u'Руководитель среднего звена', u'Индивидуальный предприниматель', u'Руководитель высшего звена', u'Руководитель низшего звена', u'Специалист', u'Высококвалифиц. специалист', u'Служащий']
    org_tp_state = [u'Частная ком. с инос. капиталом', u'Некоммерческая организация', u'Индивидуальный предприниматель', u'Государственная комп./учреж.', u'Частная компания']
    job_dir = [u'Вспомогательный техперсонал', u'Кадровая служба и секретариат', u'Реклама и маркетинг', u'Бухгалтерия, финансы, планир.', u'Юридическая служба', u'Служба безопасности', u'Адм-хоз. и трансп. службы', u'Участие в основ. деятельности', u'Снабжение и сбыт', u'Пр-техн. обесп. и телеком.']
    family_income = [ u'до 5000 руб.', u'от 20000 до 50000 руб.', u'от 10000 до 20000 руб.', u'свыше 50000 руб.', u'от 5000 до 10000 руб.']
    #tp_province = [u'Калининградская область', u'Ульяновская область', u'Пермская область', u'Сахалинская область', u'Омская область', u'Орловская область', u'Ставропольский край', u'Новгородская область', u'Воронежская область', u'Краснодарский край', u'Самарская область', u'Карелия', u'Кемеровская область', u'Смоленская область', u'Владимирская область', u'Якутия', u'Чувашия', u'Тульская область', u'Бурятия', u'Нижегородская область', u'Ханты-Мансийский АО', u'Архангельская область', u'Псковская область', u'Липецкая область', u'Кировская область', u'Свердловская область', u'Ярославская область', u'Кабардино-Балкария', u'Мурманская область', u'Башкирия', u'Приморский край', u'Москва', u'Тамбовская область', u'Пензенская область', u'Калужская область', u'Рязанская область', u'Челябинская область', u'Хабаровский край', u'Горный Алтай', u'Мордовская республика', u'Курская область', u'Тюменская область', u'Костромская область', u'Марийская республика', u'Адыгея', u'Брянская область', u'Амурская область', u'Удмуртия', u'Волгоградская область', u'Астраханская область', u'Иркутская область', u'Тверская область', u'Курганская область', u'Красноярский край', u'Читинская область', u'Санкт-Петербург', u'Белгородская область', u'Оренбургская область', u'Алтайский край', u'Ивановская область', u'Вологодская область', u'Камчатская область', u'Коми', u'Новосибирская область', u'Магаданская область', u'Еврейская АО', u'Томская область', u'Татарстан', u'Ростовская область', u'Саратовская область']
    region_num = [ u'ЗАПАДНО-СИБИРСКИЙ', u'ВОСТОЧНО-СИБИРСКИЙ', u'ПРИВОЛЖСКИЙ', u'ЮЖНЫЙ', u'ЦЕНТРАЛЬНЫЙ ОФИС', u'ПОВОЛЖСКИЙ', u'ДАЛЬНЕВОСТОЧНЫЙ', u'ЦЕНТРАЛЬНЫЙ 1', u'ЦЕНТРАЛЬНЫЙ 2', u'СЕВЕРО-ЗАПАДНЫЙ', u'УРАЛЬСКИЙ']

    df['EDUCATION'] = df['EDUCATION'].map(lambda x: education.index(x)).astype(int)
    df['GEN_INDUSTRY'] = df['GEN_INDUSTRY'].map(lambda x: gen_industry.index(x))
    df['GEN_TITLE'] = df['GEN_TITLE'].map(lambda x: gen_title.index(x))
    df['ORG_TP_STATE'] = df['ORG_TP_STATE'].map(lambda x: org_tp_state.index(x))
    df['JOB_DIR'] = df['JOB_DIR'].map(lambda x: job_dir.index(x))
    #df['TP_PROVINCE'] = df['TP_PROVINCE'].map(lambda x: tp_province.index(x))
    df['REGION_NM'] = df['REGION_NM'].map(lambda x: region_num.index(x))
    df['FAMILY_INCOME'] = df['FAMILY_INCOME'].map(lambda x: family_income.index(x))    
    ## Your Code Here
    
    return df

# %%
df_preproc = df.pipe(preproc_data)
#df_preproc.info()
df_train_preproc = df_preproc.query('sample == "train"').drop(['sample'], axis=1)
df_test_preproc = df_preproc.query('sample == "test"').drop(['sample'], axis=1)

y = df_test_preproc['TARGET']
df_test_preproc = df_test_preproc.drop(['TARGET'], axis=1)

# %% [markdown]
# #### Задание 4. Отделите целевую переменную и остальные признаки
#
# Должно получится:
# * 2 матрицы: X и X_test
# * 2 вектора: y и y_test

# %%
df_test_preproc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13563 entries, 0 to 14909
# Data columns (total 45 columns):
# AGE                    13563 non-null int64
# SOCSTATUS_WORK_FL      13563 non-null int64
# SOCSTATUS_PENS_FL      13563 non-null int64
# GENDER                 13563 non-null int64
# CHILD_TOTAL            13563 non-null int64
# DEPENDANTS             13563 non-null int64
# EDUCATION              13563 non-null int64
# MARITAL_STATUS         13563 non-null int64
# GEN_INDUSTRY           13563 non-null int64
# GEN_TITLE              13563 non-null int64
# ORG_TP_STATE           13563 non-null int64
# ORG_TP_FCAPITAL        13563 non-null int64
# JOB_DIR                13563 non-null int64
# FAMILY_INCOME          13563 non-null int64
# PERSONAL_INCOME        13563 non-null float64
# REGION_NM              13563 non-null int64
# REG_FACT_FL            13563 non-null int64
# FACT_POST_FL           13563 non-null int64
# REG_POST_FL            13563 non-null int64
# REG_FACT_POST_FL       13563 non-null int64
# REG_FACT_POST_TP_FL    13563 non-null int64
# FL_PRESENCE_FL         13563 non-null int64
# OWN_AUTO               13563 non-null int64
# AUTO_RUS_FL            13563 non-null int64
# HS_PRESENCE_FL         13563 non-null int64
# COT_PRESENCE_FL        13563 non-null int64
# GAR_PRESENCE_FL        13563 non-null int64
# LAND_PRESENCE_FL       13563 non-null int64
# CREDIT                 13563 non-null float64
# TERM                   13563 non-null int64
# FST_PAYMENT            13563 non-null float64
# DL_DOCUMENT_FL         13563 non-null int64
# GPF_DOCUMENT_FL        13563 non-null int64
# FACT_LIVING_TERM       13563 non-null int64
# WORK_TIME              13563 non-null float64
# FACT_PHONE_FL          13563 non-null int64
# REG_PHONE_FL           13563 non-null int64
# GEN_PHONE_FL           13563 non-null int64
# LOAN_NUM_TOTAL         13563 non-null int64
# LOAN_NUM_CLOSED        13563 non-null int64
# LOAN_NUM_PAYM          13563 non-null int64
# LOAN_DLQ_NUM           13563 non-null int64
# LOAN_MAX_DLQ           13563 non-null int64
# LOAN_AVG_DLQ_AMT       13563 non-null float64
# LOAN_MAX_DLQ_AMT       13563 non-null float64
# dtypes: float64(6), int64(39)
# memory usage: 4.8 MB

# %% [markdown]
# #### Задание 5. Обучение и оценка качества разных моделей

# %%
from sklearn.cross_validation import train_test_split
# test_size=0.3, random_state=42
X_train, X_test, y_train, y_test = train_test_split(df_test_preproc, y, test_size=0.3, random_state=42)

## Your Code Here

# %%
# Попробовать следующие "черные ящики": интерфейс одинаковый 
#     fit, 
#     predict, 
#     predict_proba

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

dtc = DecisionTreeClassifier()
dtc.fit(df_test_preproc, y)
predict_dtc = dtc.predict(df_test_preproc)
predict_proba_dtc = dtc.predict_proba(df_test_preproc)

rfc = RandomForestClassifier()
rfc.fit(df_test_preproc, y)
predict_rfc = rfc.predict(df_test_preproc)
predict_proba_rfc = rfc.predict_proba(df_test_preproc)

lr = LogisticRegression()
lr.fit(df_test_preproc, y)
predict_lr = lr.predict(df_test_preproc)
predict_proba_lr = lr.predict_proba(df_test_preproc)



## Your Code Here

# %%
# Посчитать метрики стандартные
# accuracy, precision, recall

from sklearn.metrics import accuracy_score, precision_score, recall_score

## Your Code Here

print('DecisionTreeClassifier: ',precision_score(y, predict_dtc), recall_score(y, predict_dtc),accuracy_score(y, predict_dtc))
print('RandomForestClassifier: ',precision_score(y, predict_rfc), recall_score(y, predict_rfc),accuracy_score(y, predict_rfc))
print('LogisticRegression: ',precision_score(y, predict_lr), recall_score(y, predict_lr),accuracy_score(y, predict_lr))
# Out:
# ('DecisionTreeClassifier: ', 1.0, 1.0, 1.0)
# ('RandomForestClassifier: ', 1.0, 0.835081585081585, 0.9791344097913441)
# ('LogisticRegression: ', 0.2857142857142857, 0.0011655011655011655, 0.8732581287325812)

# %%
predict_rfc
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# Визуалищировать эти метрики всех моделей на одном графике (чтоб визуально посмотреть)

## Your Code Here

# %matplotlib inline
from matplotlib import pyplot as plt
from sklearn.metrics import roc_auc_score, roc_curve
fpr, tpr, thresholds = roc_curve(y, predict_dtc)
plt.figure(figsize=(5, 5))
plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1])
plt.ylabel('tpr')
plt.xlabel('fpr')
plt.grid(True)
plt.title('ROC curve')
plt.xlim((-0.01, 1.01))
plt.ylim((-0.01, 1.01))
# Out:
# (-0.01, 1.01)

# %%
# Потроить roc-кривые всех можелей на одном графике
# Вывести roc_auc каждой моделе

## Your Code Here

# %%
from sklearn.cross_validation import cross_val_score
from sklearn.model_selection import StratifiedKFold
# Сделать k-fold (10 фолдов) кросс-валидацию каждой модели
# И посчитать средний roc_auc
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=123)
cross_val_score(
    dtc,
    df_test_preproc,
    y,
    scoring='roc_auc',
    cv=10,
)
## Your Code Here
# Out:
# array([0.53634334, 0.50704053, 0.5368585 , 0.49878815, 0.52499755,
#        0.52743597, 0.5164705 , 0.52720237, 0.5212581 , 0.53054864])

# %%
# Взять лучшую модель и сделать predict (с вероятностями (!!!)) для test выборки


## Your Code Here

# %%
# Померить roc_auc на тесте
